# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar el archivo CSV
df = pd.read_csv('./results/sub-68_ses-A_task-Experiment_VR_non_immersive_beh.csv')

# %%
for i in [90,91,92,93]:
    for ii in ['continuous_annotation', 'continuous_annotation_luminance']:
        # Seleccionar los valores de la columna `continuous_annotation` para id == 1
        filtered_data = df.loc[df['id'] == i, ii].iloc[0]

        list_of_lists = eval(filtered_data)

        # Extraer solo los timestamps de cada sublista
        timestamps = [pair[1] for pair in list_of_lists]

        # Calcular la diferencia entre cada punto de dato (t) y el siguiente (t+1)
        differences = [timestamps[i+1] - timestamps[i] for i in range(len(timestamps) - 1)]

        # Crear un plot para visualizar las variaciones de tiempo
        plt.plot(differences)
        plt.xlabel('Index')
        plt.ylabel('Time Difference (s)')
        plt.title(f'{i} - {ii} - Time Differences Between Consecutive Timestamps')
        plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 4
#       1 for i in [90,91,92,93]:
#       2     for ii in ['continuous_annotation', 'continuous_annotation_luminance']:
#       3         # Seleccionar los valores de la columna `continuous_annotation` para id == 1
# ----> 4         filtered_data = df.loc[df['id'] == i, ii].iloc[0]
#       6         list_of_lists = eval(filtered_data)
#       8         # Extraer solo los timestamps de cada sublista
#
# File c:\Users\Cocudata\anaconda3\envs\psychopy\lib\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# ...
